# %%
# Nama
# NIM
# 19/10/2023

# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,046 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,305 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,326 kB]
# ...

# %%
# Nama
# NIM
# 19/10/2023

# Crawl Data

filename = 'covid_belajar_daring.csv'
# search_keyword = 'piala dunia u-20 until:2023-03-28 since:2023-03-01'
# mencari informasi terkait penelitian yang dilakukan di Harvard
search_keyword = 'Covid Belajar Daring'
limit = 500

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
# Nama
# NIM
# 19/10/2023

import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(data)
# Out:
#                         created_at               id_str  \
# 0   Tue Sep 14 13:15:42 +0000 2021  1437767009782038528
# 1   Fri Mar 05 00:20:28 +0000 2021  1367631058942844930
# 2   Wed Sep 09 11:30:00 +0000 2020  1303656899813036032
# 3   Tue Oct 20 06:28:11 +0000 2020  1318438847189905408
# 4   Wed Feb 10 03:38:58 +0000 2021  1359346090693197827
# ..                             ...                  ...
# 83  Sun Sep 17 16:09:29 +0000 2023  1703441049035956582
# 84  Sun Aug 20 07:27:44 +0000 2023  1693162889044267045
# 85  Tue May 09 10:24:15 +0000 2023  1655881358382866433
# 86  Wed Jan 20 07:30:03 +0000 2021  1351794100324823040
# 87  Tue Dec 12 15:30:43 +0000 2023  1734596649975190015
#
#                                             full_text  quote_count  \
# 0   @AREAJULID Udah hampir dua tahun belajar darin...           15
# 1   Selama belajar daring aku negatif covid tapi p...            0
# 2   Ini bukan cerita baru lagi: para siswa  orangt...           12
# ...

# %%
# Nama
# NIM
# 19/10/2023

df = data.drop(columns=['created_at', 'id_str', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'lang', 'conversation_id_str', 'username', 'tweet_url'])
df
# Out:
#                                             full_text          user_id_str  \
# 0   @AREAJULID Udah hampir dua tahun belajar darin...  1146044966726066177
# 1   Selama belajar daring aku negatif covid tapi p...  1254739904631721984
# 2   Ini bukan cerita baru lagi: para siswa  orangt...           4187275698
# 3   Sahabat Demokrat  Ketua Fraksi Demokrat DPRD J...            248199104
# 4   aktifitas yang dibatasi selama PPKM  Kegiatan ...  1069768794174681089
# ..                                                ...                  ...
# 83  @tanyakanrl pernah sih  tpi itu jaman covid ba...  1256120386799853569
# 84  @kegblgnunfaedh kalo ga mau diajarin lebih bai...  1138349355784556544
# 85  @convomfs Ngerusak real life kita  dulu aku ma...  1529857315221884929
# 86  Berbagai kebijakan ditempuh untuk menekan angk...   759692754985242625
# 87  @MursidTri @kikysaputrii Lupa kali dulu awal c...           2208141222
#
#                                           image_url  \
# ...

# %%
# Nama
# NIM
# 19/10/2023

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/My Drive/Crawling_Data/covid_belajar_daring.csv')

# %%
df1 = pd.read_csv('/content/drive/My Drive/Crawling_Data/covid_belajar_daring.csv')
df1
# Out:
#     Unnamed: 0                                          full_text  \
# 0            0  @AREAJULID Udah hampir dua tahun belajar darin...
# 1            1  Selama belajar daring aku negatif covid tapi p...
# 2            2  Ini bukan cerita baru lagi: para siswa  orangt...
# 3            3  Sahabat Demokrat  Ketua Fraksi Demokrat DPRD J...
# 4            4  aktifitas yang dibatasi selama PPKM  Kegiatan ...
# ..         ...                                                ...
# 83          83  @tanyakanrl pernah sih  tpi itu jaman covid ba...
# 84          84  @kegblgnunfaedh kalo ga mau diajarin lebih bai...
# 85          85  @convomfs Ngerusak real life kita  dulu aku ma...
# 86          86  Berbagai kebijakan ditempuh untuk menekan angk...
# 87          87  @MursidTri @kikysaputrii Lupa kali dulu awal c...
#
#             user_id_str                                        image_url  \
# 0   1146044966726066177                                              NaN
# ...

# %%
# !pip install contractions
# !pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import emoji
import contractions
import re

# %%
# Nama
# NIM
# 19/10/2023

# Ketik Manual dari picture yang di share

# membersihkan teks dalam tweet.
def cleansing(tweet):
  # mengganti semua kemunculan string 'RT ' dengan string kosong ('') dalam teks tweet.
  t1 = re.sub('RT\s','',tweet)

  # mengganti semua kemunculan username Twitter dalam teks t1 dengan string kosong ('').
  # '\B' digunakan untuk mencocokkan tepi kata
  t2 = re.sub('\B@\w+','',t1)

  # menggantikan semua emoji dalam teks t2 dengan teks yang sesuai.
  t3 = emoji.demojize(t2)

  # mengganti semua URL yang dimulai dengan 'http' atau 'https' dalam teks t3 dengan string kosong ('').
  t4 = re.sub('(http|https):\/\/\S+','',t3)

  # menghilangkan satu atau lebih tanda pagar '#' dalam teks t4.
  t5 = re.sub('#+','',t4)

  # menyimpan teks t5 dalam huruf kecil (lowercase).
  t6= t5.lower()

  # mengganti semua pengulangan karakter yang terdiri dari dua atau lebih karakter dengan hanya dua karakter yang sama.
  t7 = re.sub(r'(.)\1+',r'\1\1', t6)

  # menghilangkan pengulangan tanda tanya, titik, atau tanda seru yang muncul berurutan dalam teks t7.
  t8 = re.sub(r'[\?\.\!]+(?=[\?.\!])','',t7)

  # digunakan untuk mengganti semua karakter yang bukan huruf alfabet (a-z dan A-Z) dengan spasi. Hasilnya akan disimpan di t9.
  t9 = re.sub(r'[^a-zA-Z]', ' ', t8)

  t10 = contractions.fix(t9)

  return t10

# %%
for i, r in df.iterrows():
  y = cleansing(r['full_text'])
  df1.loc[i, 'full_text'] = y

# %%
df1
# Out:
#     Unnamed: 0                                          full_text  \
# 0            0   udah hampir dua tahun belajar daring  alhamdu...
# 1            1  selama belajar daring aku negatif covid tapi p...
# 2            2  ini bukan cerita baru lagi  para siswa  orangt...
# 3            3  sahabat demokrat  ketua fraksi demokrat dprd j...
# 4            4  aktifitas yang dibatasi selama ppkm  kegiatan ...
# ..         ...                                                ...
# 83          83   pernah sih  tpi itu jaman covid baru belajar ...
# 84          84   kalo ga mau diajarin lebih baik ibu nya suruh...
# 85          85   ngerusak real life kita  dulu aku main rp pas...
# 86          86  berbagai kebijakan ditempuh untuk menekan angk...
# 87          87    lupa kali dulu awal covid  siapa yang ambil ...
#
#             user_id_str                                        image_url  \
# 0   1146044966726066177                                              NaN
# ...

# %%
df1.to_csv('/content/drive/My Drive/Crawling_Data/covid_belajar_daring2.csv')

# %%
# !pip install nltk

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
from nltk.corpus import stopwords

nltk.download('wordnet')
from nltk import pos_tag
from nltk.corpus import wordnet

nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_dict = {'J':wordnet.ADJ, 'v':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}

# %%
# Nama
# NIM
# 19/10/2023

def token_stop_pos(text):
  tags = pos_tag(word_tokenize(text))
  newlist = []
  for word, tag in tags:
    if word.lower() not in set(stopwords.words('english')):
      newlist.append(tuple([word, pos_dict.get(tag[0])]))
  return newlist

# %%
df1['POS tagged'] = df1['full_text'].apply(token_stop_pos)

# %%
df1
# Out:
#     Unnamed: 0                                          full_text  \
# 0            0   udah hampir dua tahun belajar daring  alhamdu...
# 1            1  selama belajar daring aku negatif covid tapi p...
# 2            2  ini bukan cerita baru lagi  para siswa  orangt...
# 3            3  sahabat demokrat  ketua fraksi demokrat dprd j...
# 4            4  aktifitas yang dibatasi selama ppkm  kegiatan ...
# ..         ...                                                ...
# 83          83   pernah sih  tpi itu jaman covid baru belajar ...
# 84          84   kalo ga mau diajarin lebih baik ibu nya suruh...
# 85          85   ngerusak real life kita  dulu aku main rp pas...
# 86          86  berbagai kebijakan ditempuh untuk menekan angk...
# 87          87    lupa kali dulu awal covid  siapa yang ambil ...
#
#             user_id_str                                        image_url  \
# 0   1146044966726066177                                              NaN
# ...

# %%
# Nama
# NIM
# 19/10/2023

from textblob import TextBlob

def getSubjectivity(tagged_words):
  text = ' '.join([word for word, pos_tag in tagged_words])
  return TextBlob(text).sentiment.subjectivity

def getPolarity(tagged_words):
  text = ' '.join([word for word, pos_tag in tagged_words])
  return TextBlob(text).sentiment.polarity

def analyze(score):
  if score<0:
    return 'Negative'
  elif score==0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
# Nama
# NIM
# 19/10/2023

final_data = pd.DataFrame(df1[['user_id_str','POS tagged']])
final_data
# Out:
#             user_id_str                                         POS tagged
# 0   1146044966726066177  [(udah, a), (hampir, n), (dua, n), (tahun, n),...
# 1   1254739904631721984  [(selama, n), (belajar, n), (daring, None), (a...
# 2            4187275698  [(ini, n), (bukan, n), (cerita, n), (baru, n),...
# 3             248199104  [(sahabat, n), (demokrat, n), (ketua, n), (fra...
# 4   1069768794174681089  [(aktifitas, n), (yang, None), (dibatasi, None...
# ..                  ...                                                ...
# 83  1256120386799853569  [(pernah, n), (sih, n), (tpi, n), (itu, n), (j...
# 84  1138349355784556544  [(kalo, n), (ga, n), (mau, n), (diajarin, n), ...
# 85  1529857315221884929  [(ngerusak, a), (real, a), (life, n), (kita, n...
# 86   759692754985242625  [(berbagai, n), (kebijakan, n), (ditempuh, n),...
# 87           2208141222  [(lupa, n), (kali, n), (dulu, n), (awal, n), (...
#
# [88 rows x 2 columns]

# %%
# Nama
# NIM
# 19/10/2023

final_data['Subjectivity'] = final_data['POS tagged'].apply(getSubjectivity)
final_data['Polarity'] = final_data['POS tagged'].apply(getPolarity)
final_data['TextBlob'] = final_data['Polarity'].apply(analyze)

# %%
# Nama
# NIM
# 19/10/2023

final_data
# Out:
#             user_id_str                                         POS tagged  \
# 0   1146044966726066177  [(udah, a), (hampir, n), (dua, n), (tahun, n),...
# 1   1254739904631721984  [(selama, n), (belajar, n), (daring, None), (a...
# 2            4187275698  [(ini, n), (bukan, n), (cerita, n), (baru, n),...
# 3             248199104  [(sahabat, n), (demokrat, n), (ketua, n), (fra...
# 4   1069768794174681089  [(aktifitas, n), (yang, None), (dibatasi, None...
# ..                  ...                                                ...
# 83  1256120386799853569  [(pernah, n), (sih, n), (tpi, n), (itu, n), (j...
# 84  1138349355784556544  [(kalo, n), (ga, n), (mau, n), (diajarin, n), ...
# 85  1529857315221884929  [(ngerusak, a), (real, a), (life, n), (kita, n...
# 86   759692754985242625  [(berbagai, n), (kebijakan, n), (ditempuh, n),...
# 87           2208141222  [(lupa, n), (kali, n), (dulu, n), (awal, n), (...
#
#     Subjectivity  Polarity  TextBlob
# ...

# %%
# Nama
# NIM
# 19/10/2023

final_data.to_csv('/content/drive/My Drive/Crawling_Data/covid_belajar_daring3.csv')

# %%
df1 = pd.read_csv('/content/drive/My Drive/Crawling_Data/covid_belajar_daring3.csv')
df1
# Out:
#     Unnamed: 0          user_id_str  \
# 0            0  1146044966726066177
# 1            1  1254739904631721984
# 2            2           4187275698
# 3            3            248199104
# 4            4  1069768794174681089
# ..         ...                  ...
# 83          83  1256120386799853569
# 84          84  1138349355784556544
# 85          85  1529857315221884929
# 86          86   759692754985242625
# 87          87           2208141222
#
#                                            POS tagged  Subjectivity  Polarity  \
# 0   [('udah', 'a'), ('hampir', 'n'), ('dua', 'n'),...      1.000000 -0.800000
# 1   [('selama', 'n'), ('belajar', 'n'), ('daring',...      0.000000  0.000000
# 2   [('ini', 'n'), ('bukan', 'n'), ('cerita', 'n')...      0.000000  0.000000
# 3   [('sahabat', 'n'), ('demokrat', 'n'), ('ketua'...      0.000000  0.000000
# 4   [('aktifitas', 'n'), ('yang', None), ('dibatas...      0.000000  0.000000
# ...
